# %% [markdown]
# # JSON

# %% [markdown]
# **JSON** - это особый тип данных, удобный для их хранения и передачи. Он представляет из себя либо просто словарь, либо просто список, либо список словарей. Например, вот JSON, хранящий данные четырех работ с Чтений Вернадского:
#
# ```python
# [
#     {
#         "id": "27067",
#         "number": "230001",
#         "title": "TEST",
#         "section": {
#             "id": 554,
#             "title": "Агробиология, агрохимия, защита растений (Agricultural Biology and Chemistry, Plant Protection)"
#         }
#     }
#     {
#         "id": "27068",
#         "number": "230002",
#         "title": "TEST",
#         "section": {
#             "id": 554,
#             "title": "Агробиология, агрохимия, защита растений (Agricultural Biology and Chemistry, Plant Protection)"
#         }
#     }
#     {
#         "id": "27069",
#         "number": "230003",
#         "title": "TEST",
#         "section": {
#             "id": 554,
#             "title": "Агробиология, агрохимия, защита растений (Agricultural Biology and Chemistry, Plant Protection)"
#         }
#     }
#     {
#         "id": "27070",
#         "number": "230004",
#         "title": "Гастроэзофагеальная рефлюксная болезнь у учащихся 10-11 классов",
#         "section": {
#             "id": 570,
#             "title": "Фундаментальная медицина, профилактика заболеваний, медицинская генетика (Fundamental medicine, disease prevention, medical genetics)"
#         }
#     }
# ]
# ```

# %%
works = [
    {
        "id": "27067",
        "number": "230001",
        "title": "TEST",
        "section": {
            "id": 554,
            "title": "Агробиология, агрохимия, защита растений (Agricultural Biology and Chemistry, Plant Protection)"
        }
    },
    {
        "id": "27068",
        "number": "230002",
        "title": "TEST",
        "section": {
            "id": 554,
            "title": "Агробиология, агрохимия, защита растений (Agricultural Biology and Chemistry, Plant Protection)"
        }
    },
    {
        "id": "27069",
        "number": "230003",
        "title": "TEST",
        "section": {
            "id": 554,
            "title": "Агробиология, агрохимия, защита растений (Agricultural Biology and Chemistry, Plant Protection)"
        }
    },
    {
        "id": "27070",
        "number": "230004",
        "title": "Гастроэзофагеальная рефлюксная болезнь у учащихся 10-11 классов",
        "section": {
            "id": 570,
            "title": "Фундаментальная медицина, профилактика заболеваний, медицинская генетика (Fundamental medicine, disease prevention, medical genetics)"
        }
    }
]

# %%
works[1]
# Out:
# {'id': '27068',
#  'number': '230002',
#  'title': 'TEST',
#  'section': {'id': 554,
#   'title': 'Агробиология, агрохимия, защита растений (Agricultural Biology and Chemistry, Plant Protection)'}}

# %%
import json

# %%
with open('works.json', 'w', encoding='utf-8') as f:
    json.dump(works, f)
